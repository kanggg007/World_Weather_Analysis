# %%
from citipy import citipy
import random
import numpy as np
from datetime import datetime

# %%
lats = np.random.uniform(low = -90, high = 90, size = 1500)
lngs = np.random.uniform(low = -180, high = 180, size = 1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count =+1 
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count +=1
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except KeyError:
        print("City not found. Skipping...")
        continue


print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lebu
# Processing Record 2 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=carnarvon
# Processing Record 3 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hamilton
# Processing Record 4 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=qaanaaq
# Processing Record 5 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mataura
# Processing Record 6 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mar+del+plata
# Processing Record 7 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=barrow
# Processing Record 8 of Set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=east+london
# Processing Record 10 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=salalah
# Processing Record 11 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kapaa
# Processing Record 12 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bredasdorp
# Processing Record 13 of Set 1 | show low
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=show+low
# Processing Record 14 of Set 1 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kieta
# Processing Record 15 of Set 1 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=antofagasta
# Processing Record 16 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=atuona
# Processing Record 17 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bluff
# Processing Record 18 of Set 1 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ambilobe
# Processing Record 19 of Set 1 | tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tres+arroyos
# Processing Record 20 of Set 1 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=fort+nelson
# Processing Record 21 of Set 1 | nizhniy tsasuchey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nizhniy+tsasuchey
# Processing Record 22 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hobart
# Processing Record 23 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=georgetown
# Processing Record 24 of Set 1 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nishihara
# Processing Record 25 of Set 1 | chiquinquira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=chiquinquira
# Processing Record 26 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kodiak
# Processing Record 27 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=punta+arenas
# Processing Record 28 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ushuaia
# Processing Record 29 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bethel
# Processing Record 30 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=saint-philippe
# Processing Record 31 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sao+filipe
# Processing Record 33 of Set 1 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=luanda
# Processing Record 34 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=arraial+do+cabo
# Processing Record 35 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=avarua
# Processing Record 36 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=rikitea
# Processing Record 37 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hermanus
# Processing Record 38 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=puerto+ayora
# Processing Record 39 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tuktoyaktuk
# Processing Record 40 of Set 1 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sao+jose+da+coroa+grande
# Processing Record 41 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=coquimbo
# Processing Record 42 of Set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mount+isa
# Processing Record 43 of Set 1 | nola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nola
# Processing Record 44 of Set 1 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=okha
# Processing Record 45 of Set 1 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=port+lincoln
# Processing Record 46 of Set 1 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=avera
# Processing Record 47 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=busselton
# Processing Record 48 of Set 1 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mehamn
# Processing Record 49 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=jamestown
# Processing Record 50 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cabo+san+lucas
# Processing Record 1 of Set 2 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nizwa
# Processing Record 2 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=saint+george
# Processing Record 3 of Set 2 | pirganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pirganj
# Processing Record 4 of Set 2 | almeirim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=almeirim
# Processing Record 5 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=albany
# Processing Record 6 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=port+alfred
# Processing Record 7 of Set 2 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 2 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=daru
# Processing Record 9 of Set 2 | adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=adre
# Processing Record 10 of Set 2 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ushtobe
# Processing Record 11 of Set 2 | torrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=torrington
# Processing Record 12 of Set 2 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=belushya+guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=palana
# Processing Record 14 of Set 2 | susuman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=susuman
# Processing Record 15 of Set 2 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=faya
# Processing Record 16 of Set 2 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=coihaique
# Processing Record 17 of Set 2 | elmira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=elmira
# Processing Record 18 of Set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=provideniya
# Processing Record 19 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=narsaq
# Processing Record 20 of Set 2 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lagoa
# Processing Record 21 of Set 2 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sinnamary
# Processing Record 22 of Set 2 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=merauke
# Processing Record 23 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cape+town
# Processing Record 24 of Set 2 | silver city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=silver+city
# Processing Record 25 of Set 2 | bentiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bentiu
# Processing Record 26 of Set 2 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | fort frances
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=fort+frances
# Processing Record 28 of Set 2 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=aasiaat
# Processing Record 29 of Set 2 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mercedes
# Processing Record 30 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=chokurdakh
# Processing Record 31 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=talnakh
# Processing Record 32 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=luderitz
# Processing Record 33 of Set 2 | venado tuerto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=venado+tuerto
# Processing Record 34 of Set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=new+norfolk
# Processing Record 36 of Set 2 | orocue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=orocue
# Processing Record 37 of Set 2 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=necochea
# Processing Record 38 of Set 2 | milkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=milkovo
# Processing Record 39 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=esperance
# Processing Record 40 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=aklavik
# Processing Record 41 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vila+franca+do+campo
# Processing Record 42 of Set 2 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=karratha
# Processing Record 43 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cidreira
# Processing Record 44 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nome
# Processing Record 46 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=airai
# Processing Record 47 of Set 2 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=aflu
# City not found. Skipping...
# Processing Record 48 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=severo-kurilsk
# Processing Record 49 of Set 2 | magomeni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=magomeni
# Processing Record 50 of Set 2 | cheyenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cheyenne
# Processing Record 1 of Set 3 | kvarkeno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kvarkeno
# Processing Record 2 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=norman+wells
# Processing Record 3 of Set 3 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=port+hardy
# Processing Record 4 of Set 3 | acuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=acuna
# City not found. Skipping...
# Processing Record 5 of Set 3 | dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dakar
# Processing Record 6 of Set 3 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=saleaula
# City not found. Skipping...
# Processing Record 7 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=butaritari
# Processing Record 8 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=castro
# Processing Record 9 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sitka
# Processing Record 10 of Set 3 | audru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=audru
# Processing Record 11 of Set 3 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=samarai
# Processing Record 12 of Set 3 | zhucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=zhucheng
# Processing Record 13 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mys+shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kaka
# Processing Record 15 of Set 3 | pohrebyshche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pohrebyshche
# Processing Record 16 of Set 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cherskiy
# Processing Record 17 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=longyearbyen
# Processing Record 18 of Set 3 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pacifica
# Processing Record 19 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bambous+virieux
# Processing Record 20 of Set 3 | sinegorye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sinegorye
# Processing Record 21 of Set 3 | pozo colorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pozo+colorado
# Processing Record 22 of Set 3 | ubinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ubinskoye
# Processing Record 23 of Set 3 | taylor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=taylor
# Processing Record 24 of Set 3 | aguada de pasajeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=aguada+de+pasajeros
# Processing Record 25 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=upernavik
# Processing Record 26 of Set 3 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=labuhan
# Processing Record 27 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nikolskoye
# Processing Record 28 of Set 3 | manali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=manali
# Processing Record 29 of Set 3 | khartoum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=khartoum
# Processing Record 30 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mahebourg
# Processing Record 31 of Set 3 | healesville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=healesville
# Processing Record 32 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=port+elizabeth
# Processing Record 33 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ribeira+grande
# Processing Record 34 of Set 3 | valentigney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=valentigney
# Processing Record 35 of Set 3 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=shingu
# Processing Record 36 of Set 3 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kamenka
# Processing Record 37 of Set 3 | sault sainte marie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sault+sainte+marie
# Processing Record 38 of Set 3 | dzaoudzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dzaoudzi
# Processing Record 39 of Set 3 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tazovskiy
# Processing Record 40 of Set 3 | prince albert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=prince+albert
# Processing Record 41 of Set 3 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=gat
# Processing Record 42 of Set 3 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kikwit
# Processing Record 43 of Set 3 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ixtapa
# Processing Record 44 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=yellowknife
# Processing Record 45 of Set 3 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=maragogi
# Processing Record 46 of Set 3 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=san+rafael
# Processing Record 47 of Set 3 | ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ukiah
# Processing Record 48 of Set 3 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tasiilaq
# Processing Record 49 of Set 3 | bassar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bassar
# Processing Record 50 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=fortuna
# Processing Record 1 of Set 4 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kavieng
# Processing Record 2 of Set 4 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=guerrero+negro
# Processing Record 3 of Set 4 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=erzin
# Processing Record 4 of Set 4 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vaini
# Processing Record 5 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=iqaluit
# Processing Record 6 of Set 4 | koslan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=koslan
# Processing Record 7 of Set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=la+ronge
# Processing Record 8 of Set 4 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=caravelas
# Processing Record 9 of Set 4 | yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=yatou
# Processing Record 10 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=codrington
# Processing Record 11 of Set 4 | dogondoutchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dogondoutchi
# Processing Record 12 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hithadhoo
# Processing Record 13 of Set 4 | melita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=melita
# Processing Record 14 of Set 4 | cedar city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cedar+city
# Processing Record 15 of Set 4 | dong hoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dong+hoi
# Processing Record 16 of Set 4 | chauk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=chauk
# Processing Record 17 of Set 4 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=yar-sale
# Processing Record 18 of Set 4 | nedryhayliv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nedryhayliv
# Processing Record 19 of Set 4 | surgut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=surgut
# Processing Record 20 of Set 4 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lolua
# City not found. Skipping...
# Processing Record 21 of Set 4 | synya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=synya
# Processing Record 22 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=chuy
# Processing Record 23 of Set 4 | arona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=arona
# Processing Record 24 of Set 4 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mildura
# Processing Record 25 of Set 4 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=isangel
# Processing Record 26 of Set 4 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sao+gabriel+da+cachoeira
# Processing Record 27 of Set 4 | troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=troitsko-pechorsk
# Processing Record 28 of Set 4 | algiers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=algiers
# Processing Record 29 of Set 4 | parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=parana
# Processing Record 30 of Set 4 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kaitangata
# Processing Record 31 of Set 4 | brighton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=brighton
# Processing Record 32 of Set 4 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lavrentiya
# Processing Record 34 of Set 4 | phichit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=phichit
# Processing Record 35 of Set 4 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=maldonado
# Processing Record 36 of Set 4 | albanel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=albanel
# Processing Record 37 of Set 4 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nuuk
# Processing Record 38 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nanortalik
# Processing Record 39 of Set 4 | muktsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=muktsar
# Processing Record 40 of Set 4 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=los+llanos+de+aridane
# Processing Record 41 of Set 4 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=port+augusta
# Processing Record 42 of Set 4 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bilma
# Processing Record 43 of Set 4 | kousseri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kousseri
# Processing Record 44 of Set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lompoc
# Processing Record 45 of Set 4 | dingli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dingli
# Processing Record 46 of Set 4 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=verkhnevilyuysk
# Processing Record 47 of Set 4 | vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vallenar
# Processing Record 48 of Set 4 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=yenagoa
# Processing Record 49 of Set 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lorengau
# Processing Record 50 of Set 4 | hare bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hare+bay
# Processing Record 1 of Set 5 | zhicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=zhicheng
# Processing Record 2 of Set 5 | gasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=gasa
# Processing Record 3 of Set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vostok
# Processing Record 4 of Set 5 | bhadrapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bhadrapur
# Processing Record 5 of Set 5 | stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=stykkisholmur
# Processing Record 6 of Set 5 | buchen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=buchen
# Processing Record 7 of Set 5 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=gizo
# Processing Record 8 of Set 5 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vila
# Processing Record 9 of Set 5 | itaituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=itaituba
# Processing Record 10 of Set 5 | sumbawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 5 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | amsterdam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=amsterdam
# Processing Record 13 of Set 5 | logansport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=logansport
# Processing Record 14 of Set 5 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=northam
# Processing Record 15 of Set 5 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=srednekolymsk
# Processing Record 16 of Set 5 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=buraydah
# Processing Record 17 of Set 5 | port lavaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=port+lavaca
# Processing Record 18 of Set 5 | muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=muli
# Processing Record 19 of Set 5 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=saskylakh
# Processing Record 20 of Set 5 | fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=fare
# Processing Record 21 of Set 5 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ambon
# Processing Record 22 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tiksi
# Processing Record 23 of Set 5 | quartucciu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=quartucciu
# Processing Record 24 of Set 5 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tautira
# Processing Record 25 of Set 5 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=oistins
# Processing Record 26 of Set 5 | disna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=disna
# Processing Record 27 of Set 5 | machaneng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=machaneng
# Processing Record 28 of Set 5 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=souillac
# Processing Record 29 of Set 5 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=thompson
# Processing Record 30 of Set 5 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vuktyl
# Processing Record 31 of Set 5 | douentza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=douentza
# Processing Record 32 of Set 5 | bahia blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bahia+blanca
# Processing Record 33 of Set 5 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=zhigansk
# Processing Record 34 of Set 5 | pokanayevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pokanayevka
# City not found. Skipping...
# Processing Record 35 of Set 5 | wajir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=wajir
# Processing Record 36 of Set 5 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=arlit
# Processing Record 37 of Set 5 | parras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=parras
# City not found. Skipping...
# Processing Record 38 of Set 5 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sao+felix+do+xingu
# Processing Record 39 of Set 5 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=palmer
# Processing Record 40 of Set 5 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dwarka
# Processing Record 41 of Set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=oranjemund
# Processing Record 42 of Set 5 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=san+cristobal
# Processing Record 44 of Set 5 | sindor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sindor
# Processing Record 45 of Set 5 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=deputatskiy
# Processing Record 46 of Set 5 | porto santo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=porto+santo
# Processing Record 47 of Set 5 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ilulissat
# Processing Record 48 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hasaki
# Processing Record 49 of Set 5 | camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=camopi
# Processing Record 50 of Set 5 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cabedelo
# Processing Record 1 of Set 6 | butiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=butiama
# Processing Record 2 of Set 6 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tual
# Processing Record 3 of Set 6 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pangnirtung
# Processing Record 4 of Set 6 | marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=marystown
# Processing Record 5 of Set 6 | macamic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=macamic
# Processing Record 6 of Set 6 | scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=scarborough
# Processing Record 7 of Set 6 | andover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=andover
# Processing Record 8 of Set 6 | opportunity
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=opportunity
# Processing Record 9 of Set 6 | isla vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=isla+vista
# Processing Record 10 of Set 6 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lulea
# Processing Record 11 of Set 6 | dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dali
# Processing Record 12 of Set 6 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pevek
# Processing Record 13 of Set 6 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=klaksvik
# Processing Record 14 of Set 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=leningradskiy
# Processing Record 15 of Set 6 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=halalo
# City not found. Skipping...
# Processing Record 16 of Set 6 | bafoulabe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bafoulabe
# Processing Record 17 of Set 6 | tumut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tumut
# Processing Record 18 of Set 6 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ancud
# Processing Record 19 of Set 6 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=stornoway
# Processing Record 20 of Set 6 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lac+du+bonnet
# Processing Record 21 of Set 6 | glubczyce
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=glubczyce
# Processing Record 22 of Set 6 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=la+rioja
# Processing Record 23 of Set 6 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=olinda
# Processing Record 24 of Set 6 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=roald
# Processing Record 25 of Set 6 | tibacuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tibacuy
# Processing Record 26 of Set 6 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=grand+gaube
# Processing Record 27 of Set 6 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=college
# Processing Record 28 of Set 6 | madras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=madras
# Processing Record 29 of Set 6 | kazanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kazanka
# Processing Record 30 of Set 6 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=luganville
# Processing Record 31 of Set 6 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=meulaboh
# Processing Record 32 of Set 6 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ponta+do+sol
# Processing Record 33 of Set 6 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=zhezkazgan
# Processing Record 34 of Set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vila+velha
# Processing Record 35 of Set 6 | ordynskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ordynskoye
# Processing Record 36 of Set 6 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=iquique
# Processing Record 37 of Set 6 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=san+patricio
# Processing Record 38 of Set 6 | newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=newport
# Processing Record 39 of Set 6 | buqayq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=buqayq
# City not found. Skipping...
# Processing Record 40 of Set 6 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kenora
# Processing Record 41 of Set 6 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pundaguitan
# Processing Record 42 of Set 6 | las vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=las+vegas
# Processing Record 43 of Set 6 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 6 | benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=benghazi
# Processing Record 45 of Set 6 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hovd
# Processing Record 46 of Set 6 | kachug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kachug
# Processing Record 47 of Set 6 | cambridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cambridge
# Processing Record 48 of Set 6 | kepno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kepno
# Processing Record 49 of Set 6 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=huarmey
# Processing Record 50 of Set 6 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=labuan
# Processing Record 1 of Set 7 | quzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=quzhou
# Processing Record 2 of Set 7 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=iskateley
# Processing Record 3 of Set 7 | sahrak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sahrak
# City not found. Skipping...
# Processing Record 4 of Set 7 | laa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=laa
# Processing Record 5 of Set 7 | temir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=temir
# Processing Record 6 of Set 7 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=udachnyy
# Processing Record 7 of Set 7 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 7 | barentsburg
# ...
# Processing Record 6 of Set 12 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kavaratti
# Processing Record 7 of Set 12 | qinggang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=qinggang
# Processing Record 8 of Set 12 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=shenjiamen
# Processing Record 9 of Set 12 | ilam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ilam
# Processing Record 10 of Set 12 | ust-ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ust-ishim
# Processing Record 11 of Set 12 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vao
# Processing Record 12 of Set 12 | harbour breton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=harbour+breton
# Processing Record 13 of Set 12 | hue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hue
# Processing Record 14 of Set 12 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=qasigiannguit
# Processing Record 15 of Set 12 | karkaralinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | warri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=warri
# Processing Record 17 of Set 12 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=yerbogachen
# Processing Record 18 of Set 12 | batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=batagay
# Processing Record 19 of Set 12 | yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=yining
# Processing Record 20 of Set 12 | tongren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tongren
# Processing Record 21 of Set 12 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sechura
# Processing Record 22 of Set 12 | collie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=collie
# Processing Record 23 of Set 12 | ureshino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ureshino
# Processing Record 24 of Set 12 | belle glade
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=belle+glade
# Processing Record 25 of Set 12 | baryshivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=baryshivka
# Processing Record 26 of Set 12 | sao borja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=sao+borja
# Processing Record 27 of Set 12 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=flin+flon
# Processing Record 28 of Set 12 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=arman
# Processing Record 29 of Set 12 | santiago de cao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=santiago+de+cao
# Processing Record 30 of Set 12 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=saint-joseph
# Processing Record 31 of Set 12 | primorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=primorsk
# Processing Record 32 of Set 12 | lalin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lalin
# Processing Record 33 of Set 12 | severodvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=severodvinsk
# Processing Record 34 of Set 12 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kisangani
# Processing Record 35 of Set 12 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=muros
# Processing Record 36 of Set 12 | gander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=gander
# Processing Record 37 of Set 12 | podgornoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=podgornoye
# Processing Record 38 of Set 12 | chimoio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=chimoio
# Processing Record 39 of Set 12 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kahului
# Processing Record 40 of Set 12 | tabora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tabora
# Processing Record 41 of Set 12 | antri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=antri
# Processing Record 42 of Set 12 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=warqla
# City not found. Skipping...
# Processing Record 43 of Set 12 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bontang
# Processing Record 44 of Set 12 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=plettenberg+bay
# Processing Record 45 of Set 12 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ginir
# Processing Record 46 of Set 12 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=asfi
# Processing Record 47 of Set 12 | hengyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hengyang
# Processing Record 48 of Set 12 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=half+moon+bay
# Processing Record 49 of Set 12 | urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=urucara
# Processing Record 50 of Set 12 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nantucket
# Processing Record 1 of Set 13 | gazojak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=gazojak
# Processing Record 2 of Set 13 | rudnichnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=rudnichnyy
# Processing Record 3 of Set 13 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=namibe
# Processing Record 4 of Set 13 | tahta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tahta
# Processing Record 5 of Set 13 | madhyamgram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=madhyamgram
# Processing Record 6 of Set 13 | vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=vizinga
# Processing Record 7 of Set 13 | kaohsiung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kaohsiung
# Processing Record 8 of Set 13 | store heddinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=store+heddinge
# Processing Record 9 of Set 13 | beroroha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=beroroha
# Processing Record 10 of Set 13 | clarksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=clarksburg
# Processing Record 11 of Set 13 | pinar del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pinar+del+rio
# Processing Record 12 of Set 13 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=egvekinot
# Processing Record 13 of Set 13 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cap+malheureux
# Processing Record 14 of Set 13 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hargeysa
# Processing Record 15 of Set 13 | dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dolores
# Processing Record 16 of Set 13 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nabire
# Processing Record 17 of Set 13 | lipin bor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=lipin+bor
# Processing Record 18 of Set 13 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kenai
# Processing Record 19 of Set 13 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | marshalltown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=marshalltown
# Processing Record 21 of Set 13 | alto araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=alto+araguaia
# Processing Record 22 of Set 13 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=shelburne
# Processing Record 23 of Set 13 | hirson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=hirson
# Processing Record 24 of Set 13 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=te+anau
# Processing Record 25 of Set 13 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=elko
# Processing Record 26 of Set 13 | pumiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=pumiao
# Processing Record 27 of Set 13 | chutung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=chutung
# City not found. Skipping...
# Processing Record 28 of Set 13 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ketchikan
# Processing Record 29 of Set 13 | barbastro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=barbastro
# Processing Record 30 of Set 13 | nerchinskiy zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=nerchinskiy+zavod
# Processing Record 31 of Set 13 | arteaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=arteaga
# Processing Record 32 of Set 13 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=solnechnyy
# Processing Record 33 of Set 13 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=honningsvag
# Processing Record 34 of Set 13 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=quelimane
# Processing Record 35 of Set 13 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tomatlan
# Processing Record 36 of Set 13 | dargaville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dargaville
# Processing Record 37 of Set 13 | cape canaveral
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=cape+canaveral
# Processing Record 38 of Set 13 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=noumea
# Processing Record 39 of Set 13 | matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=matamoros
# Processing Record 40 of Set 13 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=san+jeronimo
# Processing Record 41 of Set 13 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=margate
# Processing Record 42 of Set 13 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=dawlatabad
# Processing Record 43 of Set 13 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mandalgovi
# Processing Record 44 of Set 13 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bubaque
# Processing Record 45 of Set 13 | kargil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=kargil
# Processing Record 46 of Set 13 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=buala
# Processing Record 47 of Set 13 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=salinopolis
# Processing Record 48 of Set 13 | illapel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=illapel
# Processing Record 49 of Set 13 | ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=ayr
# Processing Record 50 of Set 13 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=waingapu
# Processing Record 1 of Set 14 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=christchurch
# Processing Record 2 of Set 14 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=touros
# Processing Record 3 of Set 14 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=bonthe
# Processing Record 4 of Set 14 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=mitsamiouli
# Processing Record 5 of Set 14 | tapaua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=tapaua
# City not found. Skipping...
# Processing Record 6 of Set 14 | posse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=posse
# Processing Record 7 of Set 14 | zalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7e01f7c0fc6aa7f357a1a2440cc18f45&q=zalantun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Lebu -37.62  -73.65     49.64        60           2        7.83
# 1      Carnarvon -24.87  113.63     55.40        54           0       19.46
# 2       Hamilton  39.18  -84.53     64.99        42          75        9.17
# 3        Qaanaaq  77.48  -69.36     24.60        88         100        0.60
# 4        Mataura -46.19  168.86     48.99        96         100       11.99
# 5  Mar Del Plata -38.00  -57.56     46.00        56          75       10.29
# 6         Barrow  71.29 -156.79     33.80        86          90       12.75
# 7    East London -33.02   27.91     62.08        84          97       10.78
# 8        Salalah  17.02   54.09     77.00        65           0        2.24
# 9          Kapaa  22.08 -159.32     86.00        70          40        6.93
#
#   Country                 Date
# 0      CL  2020-10-03 21:22:19
# 1      AU  2020-10-03 21:19:23
# 2      US  2020-10-03 21:21:33
# 3      GL  2020-10-03 21:22:19
# 4      NZ  2020-10-03 21:22:19
# 5      AR  2020-10-03 21:20:42
# 6      US  2020-10-03 21:22:19
# 7      ZA  2020-10-03 21:22:20
# 8      OM  2020-10-03 21:22:20
# 9      US  2020-10-03 21:22:20

# %%
new_column_order = ["City", "Country", "Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0           Lebu      CL  2020-10-03 21:22:19 -37.62  -73.65     49.64
# 1      Carnarvon      AU  2020-10-03 21:19:23 -24.87  113.63     55.40
# 2       Hamilton      US  2020-10-03 21:21:33  39.18  -84.53     64.99
# 3        Qaanaaq      GL  2020-10-03 21:22:19  77.48  -69.36     24.60
# 4        Mataura      NZ  2020-10-03 21:22:19 -46.19  168.86     48.99
# ..           ...     ...                  ...    ...     ...       ...
# 595       Touros      BR  2020-10-03 21:23:46  -5.20  -35.46     77.00
# 596       Bonthe      SL  2020-10-03 21:23:46   7.53  -12.51     78.24
# 597  Mitsamiouli      KM  2020-10-03 21:23:46 -11.38   43.28     77.13
# 598        Posse      BR  2020-10-03 21:23:46 -14.09  -46.37     87.26
# 599     Zalantun      CN  2020-10-03 21:23:46  48.00  122.72     41.65
#
#      Humidity  Cloudiness  Wind Speed
# 0          60           2        7.83
# 1          54           0       19.46
# 2          42          75        9.17
# 3          88         100        0.60
# 4          96         100       11.99
# ..        ...         ...         ...
# 595        78          95        9.17
# 596        88          97        7.43
# 597        80           1        1.61
# 598        16           0        5.93
# 599        85          91        8.14
#
# [600 rows x 9 columns]

# %%
# create output file
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
import matplotlib.pyplot as plt
import time
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
today = time.strftime("%x")

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

plt.show()

# %%
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")


plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("weather_data/Fig2.png")

plt.show()

# %%
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# crest linergression

# %%
from scipy.stats import linregress
# create a regression funcion

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=14, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.

northern_hemisphere_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemisphere_df = city_data_df.loc[(city_data_df['Lat'] < 0 )]

# %%
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Max Temp']

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\n'
                        'for Maximum Temperature', 'Max Temp',(10,40))

# %%
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Max Temp"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\n'
                        'for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# correation between Humidity and lat
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Humidity']

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\n'
                        'for Humidity', 'Humidity',(10,40))

# %%
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Humidity"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\n'
                        'for Humidity', 'Humidity',(-50,90))

# %%
# correation between Cloudiness and lat
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Cloudiness']

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\n'
                        'for Cloudiness', 'Cloudiness',(10,40))

# %%
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Cloudiness"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\n'
                        'for Cloudiness', 'Cloudiness',(-50,90))

# %%
# correation between Wind Speed and lat
x_values = northern_hemisphere_df['Lat']
y_values = northern_hemisphere_df['Wind Speed']

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\n'
                        'for Wind Speed', 'Wind Speed',(10,10))

# %%
x_values = southern_hemisphere_df['Lat']
y_values = southern_hemisphere_df['Wind Speed']

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere\n'
                        'for Wind Speed', 'Wind Speed',(-50,20))
